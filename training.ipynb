# %%
import pandas as pd
import numpy as np
import os

import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import models, layers

# %%
IMAGE_SIZE = 50
BATCH_SIZE = 32
CHANNELS = 3

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Data",
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 4000 files belonging to 2 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Negative', 'Positive']

# %%
len(dataset)
# Out:
# 125

# %%
for image_batch, leble_batch in dataset.take(1):
    print(image_batch[0].shape)
# Out:
# (50, 50, 3)

# %% [markdown]
# Shape of the 1st image is 50 x 50 and 3 is chennal color, which is RGB.

# %%
for image_batch, leble_batch in dataset.take(1):
    print(image_batch[0]) # image is in tensor, the shape is 256 x 256
# Out:
# tf.Tensor(
# [[[239. 234. 237.]
#   [229. 200. 219.]
#   [219. 170. 202.]
#   ...
#   [187. 126. 173.]
#   [201. 165. 194.]
#   [172. 108. 163.]]
#
#  [[228. 189. 216.]
#   [193. 145. 179.]
#   [204. 136. 180.]
#   ...
#   [169.  92. 149.]
#   [124.  81. 132.]
#   [201. 174. 191.]]
#
#  [[201. 144. 176.]
#   [226. 179. 208.]
#   [196. 122. 174.]
#   ...
#   [236. 219. 227.]
#   [184. 162. 180.]
#   [186. 170. 195.]]
#
#  ...
#
#  [[191. 111. 164.]
#   [191.  90. 147.]
#   [194. 124. 172.]
#   ...
#   [141. 103. 150.]
#   [202. 193. 205.]
#   [240. 236. 237.]]
#
#  [[206. 136. 180.]
#   [202. 108. 160.]
#   [182.  88. 144.]
#   ...
#   [ 95.  57. 103.]
#   [223. 210. 221.]
#   [240. 238. 237.]]
#
#  [[181. 100. 158.]
#   [208. 110. 161.]
#   [195. 108. 155.]
#   ...
#   [159. 138. 156.]
#   [242. 233. 238.]
#   [241. 238. 243.]]], shape=(50, 50, 3), dtype=float32)

# %%
plt.figure(figsize=(10,10))

for image_batch, leble_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[leble_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## Splitting the data

# %%
EPOCH = 30

# %% [markdown]
# 80% = training
# 10% = validation
# 10% = test

# %%
# Getting actual number of training data
train_size = 0.8
len(dataset) * train_size
# Out:
# 100.0

# %%
# first 54 are training data
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
# Other data is for testing and validation
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 71

# %%
# Splitting 10% for validation
val_size = 0.1
len(dataset) * val_size
# Out:
# 12.5

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
# actual test dataset
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 65

# %%
def get_dataset_partitions_tf(ds, train_split = 0.8, val_split=0.1, test_split=0.1, shuffle = True, shuffle_size = 10000):
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed = 12)
        
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)

    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)


    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %% [markdown]
# len(val_ds)

# %%
# Optimize datasets so machine could run faster
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
# For final model we need images in 50 x 50; if user gives any image other than this dimention we need to resize it
# Creating a layer for resizing and rescaling
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/50)
])

# %% [markdown]
# ### Data Augmentation

# %%
# Creating a layer for flip and rotation
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %% [markdown]
# ## Model Building

# %%
from tensorflow.keras import layers, models

input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 2  # Change to 2 for binary classification

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (32, 50, 50, 3)           0
#
#  sequential_3 (Sequential)   (32, 50, 50, 3)           0
#
#  conv2d (Conv2D)             (32, 48, 48, 32)          896
#
#  max_pooling2d (MaxPooling2  (32, 24, 24, 32)          0
#  D)
#
#  conv2d_1 (Conv2D)           (32, 22, 22, 64)          18496
#
#  max_pooling2d_1 (MaxPoolin  (32, 11, 11, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (32, 9, 9, 64)            36928
#
#  max_pooling2d_2 (MaxPoolin  (32, 4, 4, 64)            0
#  g2D)
#
#  flatten (Flatten)           (32, 1024)                0
#
#  dense (Dense)               (32, 64)                  65600
#
#  dense_1 (Dense)             (32, 2)                   130
#
# =================================================================
# Total params: 122050 (476.76 KB)
# Trainable params: 122050 (476.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
EPOCH = 60

# %%
history = model.fit(
    train_ds,
    epochs = EPOCH,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/60
# 100/100 [==============================] - 6s 45ms/step - loss: 0.4448 - accuracy: 0.7941 - val_loss: 0.3656 - val_accuracy: 0.8385
# Epoch 2/60
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3652 - accuracy: 0.8475 - val_loss: 0.3701 - val_accuracy: 0.8411
# Epoch 3/60
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3559 - accuracy: 0.8537 - val_loss: 0.4382 - val_accuracy: 0.8255
# Epoch 4/60
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3610 - accuracy: 0.8525 - val_loss: 0.3569 - val_accuracy: 0.8568
# Epoch 5/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3606 - accuracy: 0.8522 - val_loss: 0.3365 - val_accuracy: 0.8568
# Epoch 6/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3553 - accuracy: 0.8537 - val_loss: 0.3676 - val_accuracy: 0.8490
# Epoch 7/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3322 - accuracy: 0.8650 - val_loss: 0.5587 - val_accuracy: 0.7500
# Epoch 8/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3233 - accuracy: 0.8662 - val_loss: 0.3418 - val_accuracy: 0.8542
# Epoch 9/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3154 - accuracy: 0.8756 - val_loss: 0.3801 - val_accuracy: 0.8464
# Epoch 10/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3142 - accuracy: 0.8737 - val_loss: 0.3796 - val_accuracy: 0.8698
# Epoch 11/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3103 - accuracy: 0.8784 - val_loss: 0.3089 - val_accuracy: 0.8776
# Epoch 12/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2909 - accuracy: 0.8891 - val_loss: 0.4654 - val_accuracy: 0.8047
# Epoch 13/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2995 - accuracy: 0.8863 - val_loss: 0.3208 - val_accuracy: 0.8750
# Epoch 14/60
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3162 - accuracy: 0.8756 - val_loss: 0.3220 - val_accuracy: 0.8750
# Epoch 15/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2785 - accuracy: 0.8984 - val_loss: 0.3242 - val_accuracy: 0.8802
# Epoch 16/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2852 - accuracy: 0.8884 - val_loss: 0.4267 - val_accuracy: 0.8255
# Epoch 17/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2732 - accuracy: 0.8963 - val_loss: 0.2909 - val_accuracy: 0.8854
# Epoch 18/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2728 - accuracy: 0.8963 - val_loss: 0.3566 - val_accuracy: 0.8724
# Epoch 19/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2611 - accuracy: 0.9025 - val_loss: 0.2947 - val_accuracy: 0.8932
# Epoch 20/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2631 - accuracy: 0.9028 - val_loss: 0.3162 - val_accuracy: 0.8568
# Epoch 21/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2627 - accuracy: 0.9013 - val_loss: 0.2814 - val_accuracy: 0.8958
# Epoch 22/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2549 - accuracy: 0.9038 - val_loss: 0.4265 - val_accuracy: 0.8307
# Epoch 23/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2421 - accuracy: 0.9094 - val_loss: 0.3043 - val_accuracy: 0.8776
# Epoch 24/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2563 - accuracy: 0.9038 - val_loss: 0.2960 - val_accuracy: 0.8802
# Epoch 25/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2432 - accuracy: 0.9075 - val_loss: 0.3630 - val_accuracy: 0.8438
# Epoch 26/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2566 - accuracy: 0.9078 - val_loss: 0.3096 - val_accuracy: 0.8776
# Epoch 27/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2489 - accuracy: 0.9078 - val_loss: 0.4065 - val_accuracy: 0.8438
# Epoch 28/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2432 - accuracy: 0.9112 - val_loss: 0.3410 - val_accuracy: 0.8490
# Epoch 29/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2545 - accuracy: 0.9059 - val_loss: 0.3370 - val_accuracy: 0.8464
# Epoch 30/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2456 - accuracy: 0.9100 - val_loss: 0.2826 - val_accuracy: 0.8854
# Epoch 31/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2295 - accuracy: 0.9162 - val_loss: 0.2596 - val_accuracy: 0.9115
# Epoch 32/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2301 - accuracy: 0.9159 - val_loss: 0.3769 - val_accuracy: 0.8333
# Epoch 33/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2320 - accuracy: 0.9125 - val_loss: 0.2628 - val_accuracy: 0.9036
# Epoch 34/60
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2288 - accuracy: 0.9156 - val_loss: 0.2827 - val_accuracy: 0.8880
# Epoch 35/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2276 - accuracy: 0.9156 - val_loss: 0.2660 - val_accuracy: 0.9089
# Epoch 36/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2285 - accuracy: 0.9153 - val_loss: 0.2605 - val_accuracy: 0.9115
# Epoch 37/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2271 - accuracy: 0.9178 - val_loss: 0.2543 - val_accuracy: 0.9062
# Epoch 38/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2290 - accuracy: 0.9150 - val_loss: 0.2658 - val_accuracy: 0.8958
# Epoch 39/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2093 - accuracy: 0.9219 - val_loss: 0.2441 - val_accuracy: 0.9115
# Epoch 40/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2129 - accuracy: 0.9178 - val_loss: 0.2529 - val_accuracy: 0.9115
# Epoch 41/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2272 - accuracy: 0.9141 - val_loss: 0.2736 - val_accuracy: 0.9036
# Epoch 42/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2192 - accuracy: 0.9156 - val_loss: 0.2891 - val_accuracy: 0.8958
# Epoch 43/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2202 - accuracy: 0.9191 - val_loss: 0.2639 - val_accuracy: 0.8750
# Epoch 44/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2549 - accuracy: 0.8984 - val_loss: 0.3109 - val_accuracy: 0.8828
# Epoch 45/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2431 - accuracy: 0.9100 - val_loss: 0.3039 - val_accuracy: 0.8854
# Epoch 46/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2160 - accuracy: 0.9247 - val_loss: 0.2487 - val_accuracy: 0.9062
# Epoch 47/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2196 - accuracy: 0.9206 - val_loss: 0.3121 - val_accuracy: 0.8802
# Epoch 48/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2166 - accuracy: 0.9212 - val_loss: 0.2318 - val_accuracy: 0.9141
# Epoch 49/60
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2188 - accuracy: 0.9159 - val_loss: 0.2244 - val_accuracy: 0.9245
# Epoch 50/60
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2099 - accuracy: 0.9219 - val_loss: 0.2445 - val_accuracy: 0.9062
# Epoch 51/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2095 - accuracy: 0.9225 - val_loss: 0.2414 - val_accuracy: 0.9089
# Epoch 52/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2140 - accuracy: 0.9181 - val_loss: 0.2930 - val_accuracy: 0.8698
# Epoch 53/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2343 - accuracy: 0.9159 - val_loss: 0.3315 - val_accuracy: 0.8776
# Epoch 54/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2425 - accuracy: 0.9116 - val_loss: 0.2890 - val_accuracy: 0.8828
# Epoch 55/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2276 - accuracy: 0.9134 - val_loss: 0.2510 - val_accuracy: 0.8932
# Epoch 56/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2091 - accuracy: 0.9237 - val_loss: 0.2968 - val_accuracy: 0.8802
# Epoch 57/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2246 - accuracy: 0.9153 - val_loss: 0.2600 - val_accuracy: 0.8932
# Epoch 58/60
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2056 - accuracy: 0.9262 - val_loss: 0.4089 - val_accuracy: 0.8490
# Epoch 59/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2070 - accuracy: 0.9231 - val_loss: 0.2565 - val_accuracy: 0.9193
# Epoch 60/60
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2123 - accuracy: 0.9197 - val_loss: 0.2167 - val_accuracy: 0.9141

# %%
scores = model.evaluate(test_ds)
# Out:
# 13/13 [==============================] - 1s 10ms/step - loss: 0.2220 - accuracy: 0.9159

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 60, 'steps': 100}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
len(history.history['accuracy'])
# Out:
# 60

# %%
# storing params for plot
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Plotting the params

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(range(EPOCH), acc, label = "Training Accuracy")
plt.plot(range(EPOCH), val_acc, label = "Validation Accuracy")
plt.legend(loc = "lower right")
plt.title("Training and Validation Accuracy")

plt.subplot(1,2,2)
plt.plot(range(EPOCH), loss, label = "Training Loss")
plt.plot(range(EPOCH), val_loss, label = "Validation Loss")
plt.legend(loc = "upper right")
plt.title("Training and Validation Loss")

plt.show()

# %% [markdown]
# ### Prediction

# %%
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("First image to predict")
    plt.imshow(first_image)
    print("Actual label: ", class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("Predicted label: ", class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict
# Actual label:  Negative
# 1/1 [==============================] - 0s 24ms/step
# Predicted label:  Positive

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)

    return predicted_class, confidence

# %%
plt.figure(figsize = (15,15))

for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}")
        
        plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# Model_saving

# %%
# Setting up the autoincrement system for model versions

model_version = max([int(i) for i in os.listdir("saved_models") + [0]]) + 1
model_version
# Out:
# 1

# %%
# Saving a final model with updated version
model.save(f"saved_models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: saved_models/1\assets
# INFO:tensorflow:Assets written to: saved_models/1\assets

# %% [markdown]
# Saving the last model in H5 format so that there is just one file that I can upload to GCP.

# %%
model.save("latest_IDC_model.h5")
# Out:
# c:\Users\akash\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
