# %%
import pandas as pd
import numpy as np
import os

import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import models, layers

# %%
IMAGE_SIZE = 50
BATCH_SIZE = 32
CHANNELS = 3

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Data",
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 615 files belonging to 2 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['0', '1']

# %%
len(dataset)
# Out:
# 20

# %% [markdown]
# We set the batch_size 32 so all the images are stored in the batch size of 32,
#
# length of the dataset = total images / batch size
# length of the dataset = 2152 / 32
# length of the dataset = 67.25 = 68

# %%
for image_batch, leble_batch in dataset.take(1):
    print(image_batch[0].shape)
# Out:
# (50, 50, 3)

# %% [markdown]
# Shape of the 1st image is 256 x 256 and 3 is chennal color, which is RGB.

# %%
for image_batch, leble_batch in dataset.take(1):
    print(image_batch[0]) # image is in tensor, the shape is 256 x 256
# Out:
# tf.Tensor(
# [[[221. 177. 214.]
#   [213. 173. 213.]
#   [201. 124. 178.]
#   ...
#   [208. 165. 205.]
#   [207. 159. 200.]
#   [197. 150. 197.]]
#
#  [[197. 144. 191.]
#   [217. 160. 206.]
#   [210. 156. 198.]
#   ...
#   [195. 138. 189.]
#   [197. 156. 201.]
#   [195. 158. 199.]]
#
#  [[198. 132. 193.]
#   [206. 156. 199.]
#   [214. 163. 206.]
#   ...
#   [204. 110. 178.]
#   [201. 148. 196.]
#   [201. 137. 190.]]
#
#  ...
#
#  [[220. 164. 205.]
#   [221. 176. 212.]
#   [203. 145. 198.]
#   ...
#   [217. 148. 196.]
#   [202. 129. 189.]
#   [174. 111. 173.]]
#
#  [[205. 167. 205.]
#   [242. 230. 238.]
#   [207. 154. 200.]
#   ...
#   [219. 147. 202.]
#   [197. 127. 185.]
#   [209. 154. 199.]]
#
#  [[172. 107. 169.]
#   [227. 181. 216.]
#   [198. 109. 172.]
#   ...
#   [204. 116. 180.]
#   [210. 137. 193.]
#   [203. 134. 190.]]], shape=(50, 50, 3), dtype=float32)

# %%
plt.figure(figsize=(10,10))

for image_batch, leble_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[leble_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## Splitting the data

# %%
EPOCH = 30

# %% [markdown]
# 80% = training
# 10% = validation
# 10% = test

# %%
# Getting actual number of training data
train_size = 0.8
len(dataset) * train_size
# Out:
# 16.0

# %%
# first 54 are training data
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 20

# %%
# Other data is for testing and validation
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 0

# %%
# Splitting 10% for validation
val_size = 0.1
len(dataset) * val_size
# Out:
# 2.0

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 0

# %%
# actual test dataset
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 0

# %%
def get_dataset_partitions_tf(ds, train_split = 0.8, val_split=0.1, test_split=0.1, shuffle = True, shuffle_size = 10000):
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed = 12)
        
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)

    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)


    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %% [markdown]
# len(val_ds)

# %%
# Optimize datasets so machine could run faster
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
# For final model we need images in 256 x 256; if user gives any image other than this dimention we need to resize it
# Creating a layer for resizing and rescaling
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/50)
])

# %% [markdown]
# ### Data Augmentation

# %%
# Creating a layer for flip and rotation
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %% [markdown]
# ## Model Building

# %%
from tensorflow.keras import layers, models

input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 2  # Change to 2 for binary classification

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 50, 50, 3)           0
#
#  sequential_1 (Sequential)   (32, 50, 50, 3)           0
#
#  conv2d_51 (Conv2D)          (32, 48, 48, 32)          896
#
#  max_pooling2d_51 (MaxPooli  (32, 24, 24, 32)          0
#  ng2D)
#
#  conv2d_52 (Conv2D)          (32, 22, 22, 64)          18496
#
#  max_pooling2d_52 (MaxPooli  (32, 11, 11, 64)          0
#  ng2D)
#
#  conv2d_53 (Conv2D)          (32, 9, 9, 64)            36928
#
#  max_pooling2d_53 (MaxPooli  (32, 4, 4, 64)            0
#  ng2D)
#
#  flatten_14 (Flatten)        (32, 1024)                0
#
#  dense_28 (Dense)            (32, 64)                  65600
#
#  dense_29 (Dense)            (32, 2)                   130
#
# =================================================================
# Total params: 122050 (476.76 KB)
# Trainable params: 122050 (476.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
EPOCH = 60

# %%
history = model.fit(
    train_ds,
    epochs = EPOCH,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/60
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2441 - accuracy: 0.9035 - val_loss: 0.4274 - val_accuracy: 0.8125
# Epoch 2/60
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2373 - accuracy: 0.9055 - val_loss: 0.3173 - val_accuracy: 0.9219
# Epoch 3/60
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2099 - accuracy: 0.9220 - val_loss: 0.2123 - val_accuracy: 0.8906
# Epoch 4/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2405 - accuracy: 0.9014 - val_loss: 0.2828 - val_accuracy: 0.9219
# Epoch 5/60
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2187 - accuracy: 0.9158 - val_loss: 0.1970 - val_accuracy: 0.8906
# Epoch 6/60
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2331 - accuracy: 0.9097 - val_loss: 0.2110 - val_accuracy: 0.9062
# Epoch 7/60
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2776 - accuracy: 0.8768 - val_loss: 0.2959 - val_accuracy: 0.9062
# Epoch 8/60
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2291 - accuracy: 0.9117 - val_loss: 0.3156 - val_accuracy: 0.9375
# Epoch 9/60
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2269 - accuracy: 0.9179 - val_loss: 0.2526 - val_accuracy: 0.9219
# Epoch 10/60
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2301 - accuracy: 0.9138 - val_loss: 0.2340 - val_accuracy: 0.9062
# Epoch 11/60
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2550 - accuracy: 0.9076 - val_loss: 0.3269 - val_accuracy: 0.8125
# Epoch 12/60
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3259 - accuracy: 0.8686 - val_loss: 0.2463 - val_accuracy: 0.9062
# Epoch 13/60
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2436 - accuracy: 0.9014 - val_loss: 0.2172 - val_accuracy: 0.9219
# Epoch 14/60
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2436 - accuracy: 0.9076 - val_loss: 0.2850 - val_accuracy: 0.8906
# Epoch 15/60
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2441 - accuracy: 0.9158 - val_loss: 0.2202 - val_accuracy: 0.9062
# Epoch 16/60
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2335 - accuracy: 0.9138 - val_loss: 0.1789 - val_accuracy: 0.9375
# Epoch 17/60
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2067 - accuracy: 0.9261 - val_loss: 0.1805 - val_accuracy: 0.9219
# Epoch 18/60
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2198 - accuracy: 0.9097 - val_loss: 0.1732 - val_accuracy: 0.9219
# Epoch 19/60
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2414 - accuracy: 0.9035 - val_loss: 0.2493 - val_accuracy: 0.8906
# Epoch 20/60
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2398 - accuracy: 0.9138 - val_loss: 0.1717 - val_accuracy: 0.9219
# Epoch 21/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2472 - accuracy: 0.9076 - val_loss: 0.1824 - val_accuracy: 0.9375
# Epoch 22/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2389 - accuracy: 0.8994 - val_loss: 0.1939 - val_accuracy: 0.9219
# Epoch 23/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1971 - accuracy: 0.9179 - val_loss: 0.1591 - val_accuracy: 0.9688
# Epoch 24/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2186 - accuracy: 0.9097 - val_loss: 0.2689 - val_accuracy: 0.8281
# Epoch 25/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2208 - accuracy: 0.9138 - val_loss: 0.1401 - val_accuracy: 0.9375
# Epoch 26/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2294 - accuracy: 0.9179 - val_loss: 0.1527 - val_accuracy: 0.9531
# Epoch 27/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2052 - accuracy: 0.9302 - val_loss: 0.1596 - val_accuracy: 0.9219
# Epoch 28/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.3159 - accuracy: 0.8768 - val_loss: 0.3233 - val_accuracy: 0.8281
# Epoch 29/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2140 - accuracy: 0.9158 - val_loss: 0.1467 - val_accuracy: 0.9375
# Epoch 30/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2209 - accuracy: 0.9076 - val_loss: 0.2343 - val_accuracy: 0.8750
# Epoch 31/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2372 - accuracy: 0.9138 - val_loss: 0.1564 - val_accuracy: 0.9688
# Epoch 32/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2206 - accuracy: 0.9097 - val_loss: 0.1963 - val_accuracy: 0.9219
# Epoch 33/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2068 - accuracy: 0.9158 - val_loss: 0.3550 - val_accuracy: 0.7969
# Epoch 34/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2158 - accuracy: 0.9220 - val_loss: 0.1805 - val_accuracy: 0.9531
# Epoch 35/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2341 - accuracy: 0.9117 - val_loss: 0.1446 - val_accuracy: 0.9375
# Epoch 36/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.2153 - accuracy: 0.9240 - val_loss: 0.1662 - val_accuracy: 0.9375
# Epoch 37/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1981 - accuracy: 0.9199 - val_loss: 0.1328 - val_accuracy: 0.9688
# Epoch 38/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1918 - accuracy: 0.9302 - val_loss: 0.1554 - val_accuracy: 0.9688
# Epoch 39/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1794 - accuracy: 0.9220 - val_loss: 0.1586 - val_accuracy: 0.9688
# Epoch 40/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1916 - accuracy: 0.9281 - val_loss: 0.1576 - val_accuracy: 0.9375
# Epoch 41/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2014 - accuracy: 0.9138 - val_loss: 0.1186 - val_accuracy: 0.9844
# Epoch 42/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1897 - accuracy: 0.9363 - val_loss: 0.0708 - val_accuracy: 0.9844
# Epoch 43/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1991 - accuracy: 0.9322 - val_loss: 0.3954 - val_accuracy: 0.8281
# Epoch 44/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1778 - accuracy: 0.9343 - val_loss: 0.2622 - val_accuracy: 0.9219
# Epoch 45/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2536 - accuracy: 0.9076 - val_loss: 0.3012 - val_accuracy: 0.8438
# Epoch 46/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2042 - accuracy: 0.9240 - val_loss: 0.3598 - val_accuracy: 0.8281
# Epoch 47/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1971 - accuracy: 0.9199 - val_loss: 0.0828 - val_accuracy: 0.9531
# Epoch 48/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1905 - accuracy: 0.9322 - val_loss: 0.1707 - val_accuracy: 0.9531
# Epoch 49/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1886 - accuracy: 0.9446 - val_loss: 0.2140 - val_accuracy: 0.9062
# Epoch 50/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1708 - accuracy: 0.9302 - val_loss: 0.1915 - val_accuracy: 0.9219
# Epoch 51/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1663 - accuracy: 0.9425 - val_loss: 0.1443 - val_accuracy: 0.9531
# Epoch 52/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1682 - accuracy: 0.9384 - val_loss: 0.0661 - val_accuracy: 0.9844
# Epoch 53/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1648 - accuracy: 0.9363 - val_loss: 0.3098 - val_accuracy: 0.7812
# Epoch 54/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1746 - accuracy: 0.9322 - val_loss: 0.2039 - val_accuracy: 0.9688
# Epoch 55/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1648 - accuracy: 0.9405 - val_loss: 0.1912 - val_accuracy: 0.9375
# Epoch 56/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1866 - accuracy: 0.9363 - val_loss: 0.1113 - val_accuracy: 0.9531
# Epoch 57/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1666 - accuracy: 0.9322 - val_loss: 0.1720 - val_accuracy: 0.9375
# Epoch 58/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1758 - accuracy: 0.9322 - val_loss: 0.1385 - val_accuracy: 0.9531
# Epoch 59/60
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1728 - accuracy: 0.9363 - val_loss: 0.1714 - val_accuracy: 0.9531
# Epoch 60/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1672 - accuracy: 0.9384 - val_loss: 0.0888 - val_accuracy: 1.0000

# %%
scores = model.evaluate(test_ds)
# Out:
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0529 - accuracy: 1.0000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0951 - accuracy: 0.9487

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 60, 'steps': 16}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
len(history.history['accuracy'])
# Out:
# 60

# %%
# storing params for plot
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Plotting the params

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(range(EPOCH), acc, label = "Training Accuracy")
plt.plot(range(EPOCH), val_acc, label = "Validation Accuracy")
plt.legend(loc = "lower right")
plt.title("Training and Validation Accuracy")

plt.subplot(1,2,2)
plt.plot(range(EPOCH), loss, label = "Training Loss")
plt.plot(range(EPOCH), val_loss, label = "Validation Loss")
plt.legend(loc = "upper right")
plt.title("Training and Validation Loss")

plt.show()

# %% [markdown]
# ### Prediction

# %%
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("First image to predict")
    plt.imshow(first_image)
    print("Actual label: ", class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("Predicted label: ", class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict
# Actual label:  0
# 1/1 [==============================] - 0s 34ms/step
# Predicted label:  0

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)

    return predicted_class, confidence

# %%
plt.figure(figsize = (15,15))

for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}")
        
        plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step

# %% [markdown]
# Model_saving

# %%
# Setting up the autoincrement system for model versions

model_version = max([int(i) for i in os.listdir("saved_models") + [0]]) + 1
model_version
# Out:
# 2

# %%
# Saving a final model with updated version
model.save(f"saved_models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: saved_models/2\assets
# INFO:tensorflow:Assets written to: saved_models/2\assets

# %% [markdown]
# Saving the last model in H5 format so that there is just one file that I can upload to GCP.

# %%
model.save("saved_models/latest_potato_model.h5")
# Out:
# c:\Users\akash\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
